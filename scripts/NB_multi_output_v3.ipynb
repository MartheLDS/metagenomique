# %%
import numpy as np
import pandas as pd
import joblib
from sklearn.model_selection import GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, f1_score, precision_score, classification_report
from sklearn.multioutput import MultiOutputClassifier

# %%
db = 'refseq_in_house'
region = 'dna_seq' # 'dna_seq' or 'V3V4'. Will only apply to training sequences

# %%
print(db)
print(region)
# Out:
# refseq_in_house
# dna_seq

# %%
################################ Datas and variables
# paths to reference files
ref_data = '../datasets/train_sets/' + db + '.csv'


# test df import
test_df = pd.read_csv('../datasets/test_sets/test_set_from_refseq_v2.csv')


# samples sequences too classify import
unknown_df = pd.read_csv('../datasets/pre_processed_data/thresh_17/dna_sequences_17.csv')


# levels used for taxonomy
taxonomy_levels = ['domain', 'phylum', 'class', 'order', 'family', 'genus', 'species']

# %%
################################ Functions

# sequences segmentation into k-mers, returns list
def generate_kmers(sequence, k):
    """Generate k-mers from a DNA sequence."""
    kmers = []
    for i in range(len(sequence) - k + 1):
        kmers.append(sequence[i:i+k])
    kmers = ' '.join(kmers)
    return kmers

# results evaluation
def print_scores(y_true, y_pred, levels_list, score_file):
    
    for level in levels_list:
        content = ''
        content = content \
            + level \
            + '\n' \
            +  '-' * len(level) \
            + '   accuracy : ' \
            + str(accuracy_score(y_true[level], y_pred[level])) \
            + '   precision :' \
            + str(precision_score(y_true[level], y_pred[level], average = 'weighted', zero_division = np.nan)) \
            + '   score f1 :' \
            + str(f1_score(y_true[level], y_pred[level], average = 'weighted', zero_division = np.nan)) \
            + '\n' \
            + classification_report(y_true[level], y_pred[level], zero_division = np.nan) \
            + '\n\n'

        

        with open(score_file, mode = 'a') as file:
            file.write(content)

        print(content)    
    

# get predictions and probabilities for each sequence
# replace predictions with low probability with 'unclassified'
# returns lists
def pred_and_proba(preds, probas, idx, thresh):
    pred_vec = []
    proba_vec = [max(probas[k][idx]) for k in range(len(taxonomy_levels))]
    for level, proba in enumerate(proba_vec):
        if proba > thresh[level]:
            pred_vec.append(preds[idx][level])
        else:
            pred_vec.extend(["unclassified"] * (len(taxonomy_levels) - level)) # once a level is set to 'unclassified', lower levels are too
            break
        
    return pred_vec, proba_vec


# print 'unclassified' rate for each taxonomy level of a results df
def unclassified_rate(df, score_file):
    for level in taxonomy_levels:
        unclassified_count = df[level].value_counts(normalize = True)
        if 'unclassified' in unclassified_count.index:
            unclassified_rate = unclassified_count['unclassified'] * 100
        else:
            unclassified_rate = 0
        with open(score_file, mode = 'a') as file:
            file.write("Taux de 'unclassified' au rang %s: %.2f%%\n"%(level, unclassified_rate))
        print("Taux de 'unclassified' au rang %s: %.2f%%"%(level, unclassified_rate))
        
    print('\n')

# %%
################################ Sequences vectorization

# reference file importation and pre-process
known_df = pd.read_csv(ref_data)
known_df.fillna('undefined', inplace = True)
known_df.drop_duplicates(region, inplace = True)

# %%
#######################
# keep only if needed #
#######################

# remove in train_set sequences from test_set
for id in test_df['seq_id']:
    known_df = known_df.loc[(known_df['seq_id'] != id)]

# %%
# train_df sequences segmentation
known_df['kmers'] = known_df[region].apply(lambda x: generate_kmers(x, 7))

# test_df sequences segmentation
test_df['kmers'] = test_df['dna_seq'].apply(lambda x: generate_kmers(x, 7))

# train and test data
X_train = known_df['kmers']
y_train = known_df[taxonomy_levels]

X_test = test_df['kmers']
y_test = test_df[taxonomy_levels]

# Features vectorization
vectorizer = CountVectorizer()

X_train_vectorized = vectorizer.fit_transform(X_train)
X_test_vectorized = vectorizer.transform(X_test)

# %%
################################ Model training

# params for cross validation
params = {'estimator__alpha' : [1, 0.1, 0.05, 0.01, 0.005, 0.001]}

# model
model = MultinomialNB()

moc_cv_model = GridSearchCV(MultiOutputClassifier(model), param_grid = params)

moc_cv_model.fit(X_train_vectorized, y_train)

# model saving
joblib.dump(moc_cv_model, '../models/NB_' + db + '_' + region + '.joblib')
# Out:
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   self.y_type_ = type_of_target(y, input_name="y")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:359: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_is_multilabel = type_of_target(y).startswith("multilabel")
# /home/marthe/miniconda3/envs/microbiote/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:528: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y)
# ['/home/marthe/Documents/DS/projet/local/frogsdays/models/NB_refseq_in_house_dna_seq.joblib']

# %%
################################ Model prediction

moc_cv_model = joblib.load('../models/NB_' + db + '_' + region + '.joblib')

print('DONNÉES DE RÉFÉRENCE : ', db)
print('Restriction des séquences : ', region)
print('----------------------------------------------\n\n')


# predictions for test_df
y_pred_moc_cv = moc_cv_model.predict(X_test_vectorized)
y_pred_moc_cv_proba = moc_cv_model.predict_proba(X_test_vectorized)

# results agregation in dataframe, with set thresholds to get rid of low probability predictions
proba_columns = ['proba_'+level for level in taxonomy_levels]
pred_results = pd.DataFrame(columns = taxonomy_levels + proba_columns, index = X_test.index)

thresh = [0.7, 0.7, 0.7, 0.7, 0.7, 0.7, 0.7]

for k in range(pred_results.shape[0]):
    pred_vec_k, proba_vec_k = pred_and_proba(y_pred_moc_cv, y_pred_moc_cv_proba, k, thresh)
    pred_results.loc[k] = pred_vec_k + proba_vec_k

# test predictions saving
pred_results_to_save = pd.concat([test_df['seq_id'], pred_results], axis = 1)
pred_results_to_save.to_csv('../preds/NB/NB_test_' + db + '_' + region + '.csv', index = False)


score_file = '../scores/NB/scoresNB_'+ db + '_' + region + '.txt'

# test predictions evaluation
with open(score_file, mode = 'a') as file:
    file.write('DONNÉES DE RÉFÉRENCE : ' + db + '\n')
    file.write('Restriction des séquences : ' + region + '\n')
    file.write('----------------------------------------------\n\n')
unclassified_rate(pred_results, score_file)
print_scores(y_test, pred_results, taxonomy_levels, score_file)
# Out:
# DONNÉES DE RÉFÉRENCE :  refseq_in_house
# Restriction des séquences :  dna_seq
# ----------------------------------------------
#
#
# Taux de 'unclassified' au rang domain: 0.00%
# Taux de 'unclassified' au rang phylum: 0.00%
# Taux de 'unclassified' au rang class: 0.00%
# Taux de 'unclassified' au rang order: 0.00%
# Taux de 'unclassified' au rang family: 0.00%
# Taux de 'unclassified' au rang genus: 0.00%
# Taux de 'unclassified' au rang species: 4.51%
#
#
# domain
# ------   accuracy : 1.0   precision :1.0   score f1 :1.0
#               precision    recall  f1-score   support
#
#     Bacteria       1.00      1.00      1.00       843
#
#     accuracy                           1.00       843
#    macro avg       1.00      1.00      1.00       843
# weighted avg       1.00      1.00      1.00       843
#
#
#
# phylum
# ------   accuracy : 0.99644128113879   precision :0.996482822604096   score f1 :0.9964358874810249
#                          precision    recall  f1-score   support
#
#          Actinomycetota       1.00      0.98      0.99       170
#               Bacillota       0.99      1.00      0.99       254
#            Bacteroidota       1.00      1.00      1.00        71
#        Campylobacterota       1.00      1.00      1.00        14
#             Chlamydiota       1.00      1.00      1.00         2
#          Fusobacteriota       1.00      1.00      1.00         1
#          Mycoplasmatota       1.00      1.00      1.00         3
#          Pseudomonadota       1.00      1.00      1.00       320
#           Spirochaetota       1.00      1.00      1.00         2
# Thermodesulfobacteriota       1.00      1.00      1.00         2
#       Verrucomicrobiota       1.00      1.00      1.00         4
#
#                accuracy                           1.00       843
#               macro avg       1.00      1.00      1.00       843
#            weighted avg       1.00      1.00      1.00       843
#
#
#
# class
# -----   accuracy : 0.9940688018979834   precision :0.9941524691533877   score f1 :0.9939404393273259
#                        precision    recall  f1-score   support
#
#         Actinomycetes       1.00      0.99      1.00       156
#   Alphaproteobacteria       1.00      0.90      0.95        30
#               Bacilli       0.99      1.00      1.00       189
#           Bacteroidia       1.00      1.00      1.00        55
#    Betaproteobacteria       1.00      1.00      1.00        42
#            Chlamydiia       1.00      1.00      1.00         2
#            Clostridia       0.97      1.00      0.99        33
#        Coriobacteriia       1.00      1.00      1.00        14
#      Desulfovibrionia       1.00      1.00      1.00         2
# Epsilonproteobacteria       1.00      1.00      1.00        14
#      Erysipelotrichia       1.00      0.83      0.91         6
#        Flavobacteriia       1.00      1.00      1.00        16
#         Fusobacteriia       1.00      1.00      1.00         1
#   Gammaproteobacteria       0.99      1.00      0.99       248
#         Negativicutes       1.00      1.00      1.00        14
#          Spirochaetia       1.00      1.00      1.00         2
#          Tissierellia       1.00      1.00      1.00        12
#      Verrucomicrobiia       1.00      1.00      1.00         4
#             undefined       1.00      1.00      1.00         3
#
#              accuracy                           0.99       843
#             macro avg       1.00      0.99      0.99       843
#          weighted avg       0.99      0.99      0.99       843
#
#
#
# order
# -----   accuracy : 0.9952550415183867   precision :0.9956956448059652   score f1 :0.9951912642573562
#                       precision    recall  f1-score   support
#
#      Acetobacterales       1.00      1.00      1.00         1
#    Acidaminococcales       1.00      1.00      1.00         2
#      Actinomycetales       1.00      0.97      0.99        40
#        Aeromonadales       1.00      1.00      1.00        14
#      Alteromonadales       1.00      1.00      1.00         5
#           Bacillales       1.00      1.00      1.00        81
#        Bacteroidales       1.00      1.00      1.00        55
#    Bifidobacteriales       1.00      1.00      1.00         7
#      Burkholderiales       1.00      1.00      1.00        25
#    Campylobacterales       1.00      1.00      1.00        14
#      Caulobacterales       1.00      1.00      1.00         4
#   Christensenellales       1.00      1.00      1.00         1
#     Coriobacteriales       1.00      1.00      1.00         9
#   Desulfovibrionales       1.00      1.00      1.00         2
#       Eggerthellales       1.00      1.00      1.00         5
#     Enterobacterales       1.00      1.00      1.00       157
#   Erysipelotrichales       1.00      1.00      1.00         6
#             Stutzerimonas       0.75      1.00      0.86         3
#                Sutterella        nan      0.00      0.00         1
#             Tenggerimyces       0.00       nan      0.00         0
#           Thiopseudomonas       1.00      1.00      1.00         2
#            Thomasclavelia       1.00      1.00      1.00         2
#              Trabulsiella       0.00       nan      0.00         0
#               Trueperella       1.00      1.00      1.00         2
#              Turicibacter       1.00      1.00      1.00         3
#                Ureaplasma       1.00      1.00      1.00         1
#               Urinicoccus       1.00      1.00      1.00         1
#               Veillonella       1.00      1.00      1.00         2
#                    Vibrio       0.62      1.00      0.77         5
#                 Weeksella       1.00      1.00      1.00         1
#                    Winkia       1.00      1.00      1.00         3
#                 Wolinella       1.00      1.00      1.00         1
#               Xanthomonas       1.00      1.00      1.00         3
#              Xylanibacter       1.00      1.00      1.00         3
#                  Yersinia       1.00      1.00      1.00         8
#                 undefined       0.00       nan      0.00         0
#
#                  accuracy                           0.91       843
#                 macro avg       0.88      0.87      0.79       843
#              weighted avg       0.96      0.91      0.91       843
#
#
#
# species
# -------   accuracy : 0.5421115065243179   precision :0.9072346086796953   score f1 :0.5358103080523009
#                                           precision    recall  f1-score   support
#
#                    Abiotrophia defectiva       1.00      1.00      1.00         1
#                  Achromobacter insolitus       1.00      1.00      1.00         4
#               Achromobacter xylosoxidans       1.00      1.00      1.00         1
#                Acidaminococcus intestini       1.00      1.00      1.00         2
#                       Acidocella facilis       1.00      1.00      1.00         1
#                      Acidovorax defluvii       0.00       nan      0.00         0
#                       Acidovorax radicis        nan      0.00      0.00         2
#                          Acidovorax soli       0.00       nan      0.00         0
#                   Acinetobacter albensis       0.00       nan      0.00         0
#                  Acinetobacter baumannii       1.00      1.00      1.00         2
#                 Acinetobacter bereziniae       1.00      1.00      1.00         2
#              Acinetobacter calcoaceticus       1.00      1.00      1.00         3
#                 Acinetobacter guillouiae        nan      0.00      0.00         1
#               Acinetobacter haemolyticus        nan      0.00      0.00         1
#                  Acinetobacter johnsonii       0.50      0.33      0.40         3
#                     Acinetobacter oryzae       0.00       nan      0.00         0
#             Acinetobacter radioresistens       1.00      0.50      0.67         2
#                 Acinetobacter schindleri       1.00      1.00      1.00         3
#                   Acinetobacter septicus       1.00      0.50      0.67         2
#                        Acinetobacter sp.        nan      0.00      0.00         2
#                   Acinetobacter ursingii       0.00       nan      0.00         0
#                Actinobaculum massiliense        nan      0.00      0.00         2
#           Actinomyces bouchesdurhonensis       0.00       nan      0.00         0
#                     Actinomyces bowdenii       0.00       nan      0.00         0
#                 Actinomyces graevenitzii       1.00      1.00      1.00         1
#                     Actinomyces israelii       1.00      1.00      1.00         1
#                   Actinomyces naeslundii       1.00      0.50      0.67         2
#                         Actinomyces oris       0.80      1.00      0.89         4
#                          Actinomyces sp.        nan      0.00      0.00         4
#                 Actinomyces urogenitalis       0.50      1.00      0.67         1
#                     Actinomyces viscosus       1.00      1.00      1.00         1
#                   Actinotignum sanguinis       0.00       nan      0.00         0
#                    Actinotignum schaalii       1.00      0.33      0.50         3
#                 Citrobacter amalonaticus       0.00       nan      0.00         0
#                      Citrobacter braakii       0.40      1.00      0.57         2
#                      Citrobacter farmeri        nan      0.00      0.00         2
#                     Citrobacter freundii       0.33      0.50      0.40         2
#                       Citrobacter koseri       1.00      0.67      0.80         3
#                    Citrobacter murliniae       0.00       nan      0.00         0
#                     Citrobacter sedlakii       0.20      0.25      0.22         4
#                          Citrobacter sp.        nan      0.00      0.00         2
#                    Citrobacter werkmanii        nan      0.00      0.00         5
#                      Citrobacter youngae       0.00      0.00      0.00         1
#                    Clostridium butyricum       1.00      0.50      0.67         4
#                Clostridium cellulovorans       0.00       nan      0.00         0
#              Clostridium chromiireducens       0.00       nan      0.00         0
#                  Clostridium perfringens       1.00      1.00      1.00         2
#                 Clostridium putrefaciens       1.00      1.00      1.00         1
#                          Clostridium sp.        nan      0.00      0.00         1
#                  Collinsella aerofaciens       1.00      1.00      1.00         4
#                   Comamonas testosteroni        nan      0.00      0.00         1
#                    Comamonas thiooxydans       0.00       nan      0.00         0
#                       Conyzicola nivalis       0.00       nan      0.00         0
#                        Coprococcus catus        nan      0.00      0.00         1
#                     Coprococcus eutactus       1.00      1.00      1.00         2
#                 Corynebacterium accolens       1.00      1.00      1.00         1
#               Corynebacterium amycolatum       1.00      1.00      1.00         4
#              Corynebacterium aurimucosum       1.00      1.00      1.00         2
#                    Corynebacterium casei       0.00       nan      0.00         0
#                  Corynebacterium coyleae       1.00      1.00      1.00         1
#              Corynebacterium diphtheriae       1.00      1.00      1.00         5
#                Corynebacterium fournieri       0.00       nan      0.00         0
#                  Corynebacterium freneyi        nan      0.00      0.00         1
#         Corynebacterium glucuronolyticum        nan      0.00      0.00         1
#                 Corynebacterium jeikeium       1.00      1.00      1.00         1
#           Corynebacterium kroppenstedtii        nan      0.00      0.00         2
#               Corynebacterium macginleyi       1.00      1.00      1.00         1
#             Corynebacterium minutissimum       1.00      1.00      1.00         2
#              Corynebacterium mucifaciens        nan      0.00      0.00         3
#               Corynebacterium pilbarense        nan      0.00      0.00         1
#              Corynebacterium provencense       0.00       nan      0.00         0
#     Corynebacterium pseudodiphtheriticum       1.00      1.00      1.00         1
#        Corynebacterium pyruviciproducens       0.50      1.00      0.67         1
#                 Corynebacterium simulans       1.00      1.00      1.00         2
#                      Corynebacterium sp.        nan      0.00      0.00         4
#            Corynebacterium sundsvallense       1.00      1.00      1.00         1
#       Corynebacterium tuberculostearicum       1.00      1.00      1.00         2
#                 Corynebacterium ulcerans       0.00       nan      0.00         0
#              Corynebacterium urealyticum       1.00      1.00      1.00         2
#                  Corynebacterium xerosis       0.60      1.00      0.75         3
#                  Cronobacter malonaticus       0.00       nan      0.00         0
#                    Cronobacter sakazakii        nan      0.00      0.00         1
#                       Cupriavidus agavae       0.00       nan      0.00         0
#                     Cupriavidus pauculus        nan      0.00      0.00         2
#                    Cupriavidus plantarum       0.00       nan      0.00         0
#                      Cutibacterium acnes       1.00      1.00      1.00         2
#                  Fusobacterium nucleatum        nan      0.00      0.00         1
#                Fusobacterium polymorphum       0.00       nan      0.00         0
#                    Gardnerella vaginalis        nan      0.00      0.00         1
#                      Gemella haemolysans        nan      0.00      0.00         2
#                        Gemella sanguinis       1.00      1.00      1.00         2
#                      Gemella taiwanensis       0.00       nan      0.00         0
#                         Gleimia europaea       1.00      1.00      1.00         1
#          Glutamicibacter creatinolyticus        nan      0.00      0.00         2
#                  Glutamicibacter mishrai       0.00       nan      0.00         0
#                  Gordonia rubripertincta       0.00       nan      0.00         0
#                          Gordonia terrae       1.00      0.33      0.50         3
# ...
#                      Nocardia kruczakiae       0.00       nan      0.00         0
#            Nocardia rhizosphaerihabitans       0.00       nan      0.00         0
#                        Nocardia veterana        nan      0.00      0.00         4
#                  Obesumbacterium proteus       0.00       nan      0.00         0
#                      Oligella urethralis       1.00      1.00      1.00         2
#                   Orientia tsutsugamushi       1.00      1.00      1.00         2
#                      Paenibacillus alvei       1.00      1.00      1.00         2
#               Paenibacillus amylolyticus        nan      0.00      0.00         3
#                     Paenibacillus pabuli       0.00       nan      0.00         0
#                      Pantoea agglomerans       0.00       nan      0.00         0
#                         Pantoea dispersa       1.00      1.00      1.00         1
#                          Pantoea septica        nan      0.00      0.00         5
#               Parabacteroides distasonis       1.00      1.00      1.00         3
#              Parachlamydia acanthamoebae        nan      0.00      0.00         2
#             Paraclostridium bifermentans       1.00      1.00      1.00         2
#                         Parvimonas micra       1.00      1.00      1.00         3
#                    Pasteurella multocida       1.00      1.00      1.00         1
#                 Pediococcus acidilactici        nan      0.00      0.00         1
#                  Pediococcus pentosaceus       1.00      1.00      1.00         1
#                     Pediococcus stilesii       0.00       nan      0.00         0
#           Peptoniphilus asaccharolyticus       1.00      1.00      1.00         1
#                   Peptoniphilus faecalis       0.00       nan      0.00         0
#                  Peptoniphilus gorbachii       1.00      1.00      1.00         1
#                      Peptoniphilus harei       1.00      0.50      0.67         2
#            Peptostreptococcus anaerobius       1.00      1.00      1.00         2
#              Peribacillus butanolivorans       0.00       nan      0.00         0
#             Peribacillus frigoritolerans       0.00       nan      0.00         0
#                     Peribacillus simplex        nan      0.00      0.00         4
#                        Phocaeicola dorei       1.00      1.00      1.00         2
#                     Phocaeicola vulgatus       1.00      1.00      1.00         1
#                  Photobacterium damselae        nan      0.00      0.00         3
#                  Photobacterium panuliri       0.00       nan      0.00         0
#                  Pluralibacter gergoviae        nan      0.00      0.00         4
#            Porphyromonas asaccharolytica       0.00       nan      0.00         0
#                   Porphyromonas bennonis       1.00      1.00      1.00         1
#             Porphyromonas circumdentaria       1.00      1.00      1.00         1
#                    Porphyromonas uenonis       1.00      0.50      0.67         2
#                      Prevotella corporis       1.00      0.50      0.67         2
#                       Prevotella disiens       1.00      1.00      1.00         5
#                      Priestia megaterium       1.00      1.00      1.00         1
#                  Prolinoborus fasciculus       0.00       nan      0.00         0
#           Propionimicrobium lymphophilum       1.00      1.00      1.00         1
#                             Proteus cibi       0.00       nan      0.00         0
#                        Proteus mirabilis       1.00      1.00      1.00         3
#                      Proteus myxofaciens        nan      0.00      0.00         1
#                          Proteus penneri        nan      0.00      0.00         2
#                         Proteus vulgaris       0.00      0.00      0.00         2
#                Providencia alcalifaciens        nan      0.00      0.00         2
#                     Providencia rettgeri        nan      0.00      0.00         1
#                  Providencia rustigianii       0.00       nan      0.00         0
#                     Providencia stuartii       0.75      1.00      0.86         3
#                Pseudescherichia vulneris       1.00      1.00      1.00         1
#                  Pseudoclavibacter albus        nan      0.00      0.00         1
#              Pseudoglutamicibacter albus       1.00      1.00      1.00         1
#                   Pseudomonas aeruginosa       1.00      1.00      1.00         1
#                   Pseudomonas antarctica       0.00       nan      0.00         0
#                Pseudomonas citronellolis       0.00       nan      0.00         0
#    Pseudomonas denitrificans (nom. rej.)        nan      0.00      0.00         2
#                   Pseudomonas flavescens       0.00       nan      0.00         0
#                  Pseudomonas fluorescens        nan      0.00      0.00         1
#                  Pseudomonas laurentiana       0.00       nan      0.00         0
#                      Pseudomonas luteola       1.00      1.00      1.00         2
#                    Pseudomonas monteilii        nan      0.00      0.00         1
#                     Pseudomonas mosselii       1.00      1.00      1.00         1
#                Pseudomonas oryzihabitans       1.00      0.50      0.67         2
#                         Pseudomonas poae        nan      0.00      0.00         1
#                     Pseudomonas reactans        nan      0.00      0.00         1
#            Pseudomonas saudimassiliensis       0.00       nan      0.00         0
#                 Pseudomonas songnenensis       0.00       nan      0.00         0
#           Pseudoramibacter alactolyticus        nan      0.00      0.00         1
#          Pseudoruminococcus massiliensis       0.00       nan      0.00         0
#                       Rahnella aquatilis        nan      0.00      0.00         2
#                      Ralstonia pickettii       1.00      1.00      1.00         1
#               Raoultella ornithinolytica       1.00      1.00      1.00         1
#                    Raoultella planticola       0.71      1.00      0.83         5
#                     Raoultella terrigena       1.00      1.00      1.00         2
#                       Rickettsia conorii       0.00       nan      0.00         0
#                     Rickettsia fournieri       0.00       nan      0.00         0
#                      Rickettsia japonica        nan      0.00      0.00         2
#                      Rothia mucilaginosa       1.00      1.00      1.00         4
#          Ruminiclostridium cellobioparum       0.00       nan      0.00         0
#                      Ruminococcus bromii        nan      0.00      0.00         3
#             Ruminococcus champanellensis       0.00       nan      0.00         0
#                Ruminococcus flavefaciens        nan      0.00      0.00         1
#            Saccharofermentans acetigenes       0.00       nan      0.00         0
#                      Salmonella enterica       1.00      1.00      1.00         8
#                    Schaalia odontolytica       0.75      0.75      0.75         4
#                        Segatella salivae       0.00       nan      0.00         0
#                       Serratia aquatilis       0.00       nan      0.00         0
#                       Serratia fonticola       0.60      1.00      0.75         3
#                    Serratia liquefaciens       1.00      1.00      1.00         1
#                      Serratia marcescens       1.00      1.00      1.00         4
#                          Serratia myotis       0.00       nan      0.00         0
#                       Serratia odorifera       1.00      1.00      1.00         2
#                     Serratia quinivorans        nan      0.00      0.00         2
#                        Serratia rubidaea       1.00      1.00      1.00         3
#                       Sharpea azabuensis       0.00       nan      0.00         0
#                      Shewanella profunda       0.00       nan      0.00         0
#                  Shewanella putrefaciens       1.00      0.40      0.57         5
#                    Shewanella seohaensis       0.00       nan      0.00         0
#                          Shigella boydii       0.00       nan      0.00         0
#                     Shigella dysenteriae       0.50      0.33      0.40         3
#                        Shigella flexneri       0.50      0.25      0.33         4
#                          Shigella sonnei        nan      0.00      0.00         2
#                           Slackia exigua        nan      0.00      0.00         1
#               Slackia heliotrinireducens       0.00       nan      0.00         0
#                      Sphingobium xanthum       1.00      1.00      1.00         1
#                Sphingomonas paucimobilis       1.00      1.00      1.00         1
#              Sporolactobacillus inulinus       1.00      0.50      0.67         4
#         Sporolactobacillus pectinivorans       0.00       nan      0.00         0
#                   Staphylococcus agnetis       0.00       nan      0.00         0
#                    Staphylococcus aureus        nan      0.00      0.00         2
#                   Staphylococcus capitis        nan      0.00      0.00         2
#                    Staphylococcus caprae       0.50      1.00      0.67         2
#               Staphylococcus chromogenes       1.00      1.00      1.00         4
#                    Staphylococcus cohnii        nan      0.00      0.00         2
#                Staphylococcus condimenti        nan      0.00      0.00         2
#                 Staphylococcus edaphicus       0.00       nan      0.00         0
#               Staphylococcus epidermidis       0.50      1.00      0.67         2
#              Staphylococcus haemolyticus        nan      0.00      0.00         1
#                   Staphylococcus hominis       1.00      1.00      1.00         5
#                    Staphylococcus hyicus        nan      0.00      0.00         5
#               Staphylococcus lugdunensis       1.00      0.67      0.80         3
#                Staphylococcus nepalensis        nan      0.00      0.00         1
#                  Staphylococcus pasteuri       1.00      1.00      1.00         2
#                  Staphylococcus petrasii        nan      0.00      0.00         1
#           Staphylococcus piscifermentans       0.00       nan      0.00         0
#                 Staphylococcus pragensis       0.00       nan      0.00         0
#             Staphylococcus saprophyticus        nan      0.00      0.00         1
#                  Staphylococcus simulans       1.00      1.00      1.00         3
#               Staphylococcus ureilyticus       0.00       nan      0.00         0
#                   Staphylococcus warneri       0.67      1.00      0.80         2
#             Stenotrophomonas hibiscicola       0.00       nan      0.00         0
#             Stenotrophomonas maltophilia       1.00      0.50      0.67         2
#               Streptococcus acidominimus       1.00      0.71      0.83         7
#                 Streptococcus agalactiae        nan      0.00      0.00         2
#              Streptococcus alactolyticus       0.00       nan      0.00         0
#                  Streptococcus anginosus       1.00      1.00      1.00         2
#                      Streptococcus canis       1.00      1.00      1.00         1
#               Streptococcus constellatus       1.00      1.00      1.00         1
#                  Streptococcus cristatus        nan      0.00      0.00         2
#               Streptococcus dysgalactiae       0.50      1.00      0.67         2
#                    Streptococcus equinus        nan      0.00      0.00         2
#               Streptococcus gallolyticus        nan      0.00      0.00         2
#                   Streptococcus gordonii       1.00      1.00      1.00         2
#               Streptococcus hyovaginalis       0.00       nan      0.00         0
#                       Streptococcus ilei       0.00       nan      0.00         0
#                Streptococcus lutetiensis       0.00       nan      0.00         0
#                      Streptococcus mitis       0.44      1.00      0.62         4
#              Streptococcus parasanguinis        nan      0.00      0.00         3
#               Streptococcus pasteurianus        nan      0.00      0.00         2
#              Streptococcus pluranimalium       0.00       nan      0.00         0
#                 Streptococcus pneumoniae       1.00      0.33      0.50         3
#                   Streptococcus porcinus        nan      0.00      0.00         3
#           Streptococcus pseudopneumoniae        nan      0.00      0.00         3
#             Streptococcus pseudoporcinus        nan      0.00      0.00         1
#                   Streptococcus pyogenes       1.00      1.00      1.00         2
#                    Streptococcus rubneri       0.00       nan      0.00         0
#                 Streptococcus salivarius       0.60      1.00      0.75         3
#               Streptococcus thermophilus       1.00      1.00      1.00         2
#                   Streptococcus urinalis       1.00      1.00      1.00         2
#               Streptococcus vestibularis        nan      0.00      0.00         2
#               Streptomyces albogriseolus        nan      0.00      0.00         3
#                   Stutzerimonas stutzeri       1.00      1.00      1.00         3
#                 Sutterella stercoricanis        nan      0.00      0.00         1
#                     Tenggerimyces flavus       0.00       nan      0.00         0
#              Thiopseudomonas alkaliphila       1.00      1.00      1.00         2
#                    Thomasclavelia ramosa       1.00      1.00      1.00         2
#                   Trabulsiella guamensis       0.00       nan      0.00         0
#                   Trueperella abortisuis       0.00       nan      0.00         0
#                   Trueperella bernardiae        nan      0.00      0.00         2
#                   Turicibacter sanguinis       1.00      1.00      1.00         3
#                        Ureaplasma parvum       1.00      1.00      1.00         1
#                 Urinicoccus massiliensis       1.00      1.00      1.00         1
#                       Veillonella dispar       0.00       nan      0.00         0
#             Veillonella montpellierensis       1.00      1.00      1.00         1
#                      Veillonella parvula        nan      0.00      0.00         1
#                          Vibrio cholerae       1.00      0.67      0.80         3
#                           Vibrio mimicus       0.00       nan      0.00         0
#                        Vibrio vulnificus       1.00      1.00      1.00         2
#                   Weeksella massiliensis       1.00      1.00      1.00         1
#                             Winkia neuii       1.00      1.00      1.00         3
#                   Wolinella succinogenes       1.00      1.00      1.00         1
#                   Xanthomonas arboricola        nan      0.00      0.00         3
#                         Xanthomonas dyei       0.00       nan      0.00         0
#                      Xylanibacter brevis       0.00       nan      0.00         0
#                  Xylanibacter ruminicola       1.00      0.67      0.80         3
#                      Yersinia aleksiciae       0.00       nan      0.00         0
#                  Yersinia enterocolitica       1.00      0.33      0.50         3
#                    Yersinia kristensenii       1.00      1.00      1.00         2
#              Yersinia pseudotuberculosis       1.00      1.00      1.00         3
#                             unclassified       0.00       nan      0.00         0
#
#                                 accuracy                           0.54       843
#                                macro avg       0.55      0.55      0.38       843
#                             weighted avg       0.91      0.54      0.54       843

# %%
# # ############################### Samples sequences classification
# # sequences segmentation
# unknown_df['kmers'] = unknown_df['dna_seq'].apply(lambda x: generate_kmers(x, 7))

# # features vectorization
# X_unknown = unknown_df['kmers']
# X_unknown_vectorized = vectorizer.transform(X_unknown)

# # prediction
# samples_prediction = moc_cv_model.predict(X_unknown_vectorized)
# samples_proba = moc_cv_model.predict_proba(X_unknown_vectorized)

# # results agregation in dataframe, with set thresholds to get rid of low probability predictions
# proba_columns = ['proba_'+level for level in taxonomy_levels]
# samples_results = pd.DataFrame(columns = ['seq_id'] + taxonomy_levels + proba_columns, index = X_test.index)

# thresh = [0.7, 0.7, 0.7, 0.7, 0.7, 0.7, 0.7]

# for k in range(samples_prediction.shape[0]):
#     seq_id = [unknown_df['seq_id'][k]]
#     pred_vec_k, proba_vec_k = pred_and_proba(samples_prediction, samples_proba, k, thresh)
#     item = seq_id + pred_vec_k + proba_vec_k
#     samples_results.loc[k] = item

# # samples prediction saving
# samples_results.to_csv('/home/marthe/Documents/DS/projet/local/frogsdays/preds/samples/NB_samples_' + db + '_' + region + '.csv', index = False)

# %%
preds = pd.DataFrame(y_pred_moc_cv, columns = taxonomy_levels, index = X_test.index)
preds
# Out:
#        domain          phylum                class            order  \
# 0    Bacteria  Pseudomonadota  Gammaproteobacteria  Alteromonadales
# 1    Bacteria       Bacillota           Clostridia    Eubacteriales
# 2    Bacteria  Actinomycetota        Actinomycetes    Micrococcales
# 3    Bacteria  Pseudomonadota   Betaproteobacteria  Burkholderiales
# 4    Bacteria       Bacillota              Bacilli  Lactobacillales
# ..        ...             ...                  ...              ...
# 838  Bacteria  Actinomycetota        Actinomycetes    Micrococcales
# 839  Bacteria  Actinomycetota        Actinomycetes  Actinomycetales
# 840  Bacteria  Actinomycetota        Actinomycetes    Micrococcales
# 841  Bacteria  Pseudomonadota   Betaproteobacteria  Burkholderiales
# 842  Bacteria  Actinomycetota        Actinomycetes  Mycobacteriales
#
#                 family                  genus  \
# 0       Shewanellaceae             Shewanella
# 1     Oscillospiraceae       Faecalibacterium
# 2       Micrococcaceae  Pseudoglutamicibacter
# 3       Comamonadaceae              Comamonas
# 4     Streptococcaceae          Streptococcus
# ..                 ...                    ...
# 838     Micrococcaceae   Paeniglutamicibacter
# 839   Actinomycetaceae        Arcanobacterium
# 840  Microbacteriaceae         Microbacterium
# 841   Burkholderiaceae            Cupriavidus
# 842   Mycobacteriaceae        Mycobacteroides
#
#                               species
# 0             Shewanella putrefaciens
# 1        Faecalibacterium prausnitzii
# 2         Pseudoglutamicibacter albus
# 3               Comamonas thiooxydans
# 4            Streptococcus pneumoniae
# ..                                ...
# 838           Glutamicibacter mishrai
# 839  Arcanobacterium urinimassiliense
# 840     Microbacterium ginsengiterrae
# 841             Cupriavidus plantarum
# 842        Mycobacteroides franklinii
#
# [843 rows x 7 columns]

# %%
score_file = '../scores/recap_scores.csv'

with open(score_file, mode = 'a') as file:
    for level in taxonomy_levels[-3:]:
        true_labels = y_test[level]
        pred_labels = preds[level]
        print(level)
        accuracy = accuracy_score(true_labels, pred_labels)
        print(accuracy)
        precision = precision_score(true_labels, pred_labels, average = 'weighted', zero_division = np.nan)
        print(precision)
        f1 = f1_score(true_labels, pred_labels, average = 'weighted', zero_division = np.nan)
        print(f1)
        
        file.write('NB, {}, {}, {}, {}, {}, {}\n'.format(db, region, level, accuracy, precision, f1))
# Out:
# family
# 0.9881376037959668
# 0.989574143196471
# 0.9875492831649438
# genus
# 0.9134045077105575
# 0.9641075086751119
# 0.9102209856313448
# species
# 0.5599051008303677
# 0.9018479033404406
# 0.5506044107467595
